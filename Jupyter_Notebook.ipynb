# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <b>KENNEDY SITATI NAVISWA</b>
# <br/>
# Data Scientist

# %% [markdown]
# <i>I am interested in Data Science because I would love to use data to create an impact in the agricultural field using available data</i>

# %% [markdown]
# ### My code below is going to print each of my names in three separate lines ###

# %%
print("Kennedy\nSitati\nNaviswa")
# Out:
# Kennedy
# Sitati
# Naviswa

# %% [markdown]
# --- ---
# <ol>
# <li>One</li>
# <li>Two</li>
# <li>Three</li>
# <li>Four</li>
# </ol>
#
# --- ---
#
# <ul>
# <li>One</li>
# <li>Two</li>
# <li>Three</li>
# <li>Four</li>
# </ul>
#
# --- ---
# <a href="https://www.google.com">Google</a>
